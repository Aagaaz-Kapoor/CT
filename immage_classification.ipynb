# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
import pandas as pd
import os

csv_path = "C:\\Users\\Aagaaz Kapoor\\Desktop\\CT\\final project\\train.csv"
image_folder = r"C:\Users\Aagaaz Kapoor\Desktop\CT\images"  

df = pd.read_csv(csv_path)
print(df.head())
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
image_size = (128, 128)
# Store image data
image_data = []

for img_id in df['image_id']:
    img_path = os.path.join(image_folder, f"{img_id}.jpg")
    
    # Read image using OpenCV
    img = cv2.imread(img_path)
    
    if img is not None:
        # Resize image
        img = cv2.resize(img, image_size)
        # Optionally convert to grayscale
        # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        image_data.append(img)
    else:
        print(f"Warning: {img_path} not found or couldn't be read.")

# %%
from skimage.feature import hog
import cv2

# %%
def extract_features(img, use_hog=True, use_color_hist=True):
    features = []

    # Resize image to ensure consistency (already done before calling this)
    # Convert to grayscale for HOG
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    if use_hog:
        # HOG feature extraction
        hog_features = hog(
            gray,
            orientations=9,
            pixels_per_cell=(8, 8),
            cells_per_block=(2, 2),
            block_norm='L2-Hys',
            transform_sqrt=True,
            feature_vector=True
        )
        features.extend(hog_features)
    
    if use_color_hist:
        # Color Histogram (in RGB)
        chans = cv2.split(img)
        hist_features = []
        for chan in chans:
            hist = cv2.calcHist([chan], [0], None, [32], [0, 256])
            hist = cv2.normalize(hist, hist).flatten()
            hist_features.extend(hist)
        features.extend(hist_features)
    
    return features

# %%
# Assume `image_data` is already populated with resized images
X_features = []

for i, img in enumerate(image_data):
    feats = extract_features(img)
    X_features.append(feats)

X_features = np.array(X_features)
print("Feature matrix shape:", X_features.shape)
# Out:
# Feature matrix shape: (1821, 8196)

# %%
# One-hot columns: ['healthy', 'multiple_diseases', 'rust', 'scab']
# Convert to single label
labels = df[['healthy', 'multiple_diseases', 'rust', 'scab']].idxmax(axis=1)
labels = labels.map({
    'healthy': 0,
    'multiple_diseases': 1,
    'rust': 2,
    'scab': 3
})
y = labels.values

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# X_features and y are assumed from the previous step
X_train, X_test, y_train, y_test = train_test_split(
    X_features, y, test_size=0.2, random_state=42, stratify=y
)

# %%
scaler = StandardScaler()

# Fit only on training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform test data using the same scaler
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import xgboost as xgb  # Make sure to install it using: pip install xgboost

# %%
# SVM
svm_model = SVC(kernel='rbf', probability=True, random_state=42)
svm_model.fit(X_train_scaled, y_train)
# Out:
# SVC(probability=True, random_state=42)

# %%
# Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)  # No scaling needed for Random Forest
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Gradient Boosting (XGBoost)
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
xgb_model.fit(X_train, y_train)
# Out:
# c:\Users\Aagaaz Kapoor\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:22:04] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
models = {
    'SVM': svm_model,
    'Random Forest': rf_model,
    'XGBoost': xgb_model
}

for name, model in models.items():
    print(f"\n=== {name} ===")
    
    # Select test set (scaled for SVM, raw for tree models)
    X_test_used = X_test_scaled if name == 'SVM' else X_test
    
    y_pred = model.predict(X_test_used)
    
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# === SVM ===
# Accuracy: 0.5013698630136987
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.43      0.47       103
#            1       0.00      0.00      0.00        18
#            2       0.47      0.58      0.52       125
#            3       0.52      0.55      0.54       119
#
#     accuracy                           0.50       365
#    macro avg       0.38      0.39      0.38       365
# weighted avg       0.48      0.50      0.49       365
#
# Confusion Matrix:
#  [[44  0 36 23]
#  [ 5  0  7  6]
#  [20  0 73 32]
#  [14  1 38 66]]
#
# === Random Forest ===
# Accuracy: 0.5013698630136987
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.41      0.48       103
#            1       0.00      0.00      0.00        18
#            2       0.46      0.63      0.53       125
#            3       0.51      0.52      0.52       119
#
#     accuracy                           0.50       365
#    macro avg       0.39      0.39      0.38       365
# weighted avg       0.49      0.50      0.49       365
#
# Confusion Matrix:
#  [[42  0 43 18]
#  [ 1  0  9  8]
#  [13  0 79 33]
#  [15  1 41 62]]
#
# === XGBoost ===
# Accuracy: 0.5616438356164384
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.53      0.56       103
#            1       0.00      0.00      0.00        18
#            2       0.53      0.62      0.57       125
#            3       0.57      0.61      0.59       119
#
#     accuracy                           0.56       365
#    macro avg       0.43      0.44      0.43       365
# weighted avg       0.54      0.56      0.55       365
#
# Confusion Matrix:
#  [[55  0 28 20]
#  [ 3  0  7  8]
#  [21  0 77 27]
#  [13  1 32 73]]

# %%
import joblib

# Save the SVM model
joblib.dump(svm_model, 'svm_model.pkl')

# Also save the scaler used (important for preprocessing test data)
joblib.dump(scaler, 'svm_scaler.pkl')

print("✅ SVM model and scaler saved.")
# Out:
# ✅ SVM model and scaler saved.

# %%
# Load the saved model and scaler
svm_model = joblib.load('svm_model.pkl')
scaler = joblib.load('svm_scaler.pkl')

print("✅ SVM model and scaler loaded.")
# Out:
# ✅ SVM model and scaler loaded.

# %%
import cv2
import os
import numpy as np

def extract_features(img):
    features = []

    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # HOG
    from skimage.feature import hog
    hog_features = hog(
        gray,
        orientations=9,
        pixels_per_cell=(8, 8),
        cells_per_block=(2, 2),
        block_norm='L2-Hys',
        transform_sqrt=True,
        feature_vector=True
    )
    features.extend(hog_features)

    # Color Histogram (in RGB)
    chans = cv2.split(img)
    for chan in chans:
        hist = cv2.calcHist([chan], [0], None, [32], [0, 256])
        hist = cv2.normalize(hist, hist).flatten()
        features.extend(hist)

    return features

# %%
test_image_folder = r"C:\Users\Aagaaz Kapoor\Desktop\CT\images"
image_size = (128, 128)

# Prepare feature list and filenames
X_test_final = []
image_ids = []

for filename in os.listdir(test_image_folder):
    if filename.endswith(".jpg"):
        img_path = os.path.join(test_image_folder, filename)
        img = cv2.imread(img_path)

        if img is not None:
            img = cv2.resize(img, image_size)
            features = extract_features(img)
            X_test_final.append(features)
            image_ids.append(filename.split('.')[0])  # remove .jpg
        else:
            print(f"❌ Failed to read {filename}")

# Convert to NumPy and scale
X_test_final = scaler.transform(np.array(X_test_final))

# Predict
y_pred = svm_model.predict(X_test_final)

# Map numeric label back to category
label_map = {0: 'healthy', 1: 'multiple_diseases', 2: 'rust', 3: 'scab'}
predictions = [label_map[i] for i in y_pred]

# Show results
for img_id, pred in zip(image_ids, predictions):
    print(f"{img_id}: {pred}")
# Out:
# Test_0: scab
# Test_1: rust
# Test_10: rust
# Test_100: rust
# Test_1000: scab
# Test_1001: healthy
# Test_1002: rust
# Test_1003: rust
# Test_1004: rust
# Test_1005: healthy
# Test_1006: scab
# Test_1007: scab
# Test_1008: scab
# Test_1009: healthy
# Test_101: healthy
# Test_1010: rust
# Test_1011: healthy
# Test_1012: rust
# Test_1013: rust
# Test_1014: rust
# Test_1015: scab
# Test_1016: scab
# Test_1017: rust
# Test_1018: scab
# Test_1019: scab
# Test_102: rust
# Test_1020: healthy
# Test_1021: healthy
# Test_1022: rust
# Test_1023: healthy
# Test_1024: scab
# Test_1025: rust
# Test_1026: rust
# Test_1027: scab
# Test_1028: healthy
# Test_1029: rust
# Test_103: healthy
# Test_1030: rust
# Test_1031: scab
# Test_1032: scab
# Test_1033: healthy
# Test_1034: healthy
# Test_1035: rust
# Test_1036: rust
# Test_1037: healthy
# Test_1038: scab
# Test_1039: rust
# Test_104: scab
# Test_1040: scab
# Test_1041: scab
# Test_1042: rust
# Test_1043: rust
# Test_1044: rust
# Test_1045: scab
# Test_1046: scab
# Test_1047: healthy
# Test_1048: scab
# Test_1049: rust
# Test_105: rust
# Test_1050: healthy
# Test_1051: scab
# Test_1052: healthy
# Test_1053: scab
# Test_1054: rust
# Test_1055: healthy
# Test_1056: healthy
# Test_1057: scab
# Test_1058: rust
# Test_1059: healthy
# Test_106: rust
# Test_1060: rust
# Test_1061: scab
# Test_1062: healthy
# Test_1063: rust
# Test_1064: healthy
# Test_1065: rust
# Test_1066: scab
# Test_1067: scab
# Test_1068: rust
# Test_1069: scab
# Test_107: healthy
# Test_1070: healthy
# Test_1071: scab
# Test_1072: healthy
# Test_1073: scab
# Test_1074: healthy
# Test_1075: scab
# Test_1076: rust
# Test_1077: rust
# Test_1078: healthy
# Test_1079: healthy
# Test_108: rust
# Test_1080: rust
# Test_1081: scab
# Test_1082: scab
# Test_1083: scab
# Test_1084: rust
# Test_1085: rust
# Test_1086: scab
# Test_1087: rust
# Test_1088: rust
# Test_1089: rust
# Test_109: healthy
# Test_1090: rust
# Test_1091: rust
# Test_1092: rust
# Test_1093: scab
# Test_1094: healthy
# Test_1095: scab
# Test_1096: rust
# Test_1097: rust
# Test_1098: scab
# Test_1099: scab
# Test_11: rust
# Test_110: rust
# Test_1100: healthy
# Test_1101: rust
# Test_1102: scab
# Test_1103: scab
# Test_1104: healthy
# Test_1105: scab
# Test_1106: scab
# Test_1107: rust
# Test_1108: healthy
# Test_1109: healthy
# Test_111: rust
# Test_1110: healthy
# Test_1111: scab
# Test_1112: healthy
# Test_1113: rust
# Test_1114: rust
# Test_1115: rust
# Test_1116: rust
# Test_1117: healthy
# Test_1118: rust
# Test_1119: rust
# Test_112: scab
# Test_1120: scab
# Test_1121: scab
# Test_1122: scab
# Test_1123: rust
# Test_1124: healthy
# Test_1125: scab
# Test_1126: healthy
# Test_1127: rust
# Test_1128: healthy
# Test_1129: scab
# Test_113: scab
# Test_1130: scab
# Test_1131: rust
# Test_1132: scab
# Test_1133: rust
# Test_1134: rust
# Test_1135: scab
# Test_1136: rust
# Test_1137: scab
# Test_1138: scab
# Test_1139: scab
# Test_114: scab
# Test_1140: healthy
# Test_1141: scab
# Test_1142: scab
# Test_1143: scab
# Test_1144: rust
# Test_1145: rust
# Test_1146: rust
# Test_1147: scab
# Test_1148: scab
# Test_1149: healthy
# Test_115: scab
# Test_1150: healthy
# Test_1151: rust
# Test_1152: scab
# Test_1153: healthy
# Test_1154: healthy
# Test_1155: scab
# Test_1156: scab
# Test_1157: rust
# Test_1158: healthy
# Test_1159: rust
# Test_116: rust
# Test_1160: scab
# Test_1161: scab
# Test_1162: scab
# Test_1163: healthy
# Test_1164: healthy
# Test_1165: rust
# Test_1166: scab
# Test_1167: rust
# Test_1168: rust
# Test_1169: scab
# Test_117: healthy
# Test_1170: scab
# Test_1171: scab
# Test_1172: healthy
# Test_1173: rust
# Test_1174: rust
# Test_1175: scab
# Test_1176: scab
# Test_1177: healthy
# Test_1178: healthy
# Test_1179: rust
# Test_118: rust
# Test_1180: healthy
# Test_1181: rust
# Test_1182: scab
# Test_1183: rust
# Test_1184: rust
# Test_1185: scab
# Test_1186: rust
# Test_1187: scab
# Test_1188: healthy
# Test_1189: scab
# Test_119: healthy
# Test_1190: rust
# Test_1191: rust
# Test_1192: scab
# Test_1193: scab
# Test_1194: healthy
# Test_1195: scab
# Test_1196: scab
# Test_1197: rust
# Test_1198: rust
# Test_1199: rust
# Test_12: rust
# Test_120: scab
# Test_1200: scab
# Test_1201: scab
# Test_1202: scab
# Test_1203: healthy
# Test_1204: scab
# Test_1205: rust
# Test_1206: healthy
# Test_1207: rust
# Test_1208: scab
# Test_1209: rust
# Test_121: scab
# Test_1210: scab
# Test_1211: scab
# Test_1212: rust
# Test_1213: scab
# Test_1214: healthy
# Test_1215: healthy
# Test_1216: rust
# Test_1217: rust
# Test_1218: scab
# Test_1219: healthy
# Test_122: scab
# Test_1220: scab
# Test_1221: rust
# Test_1222: rust
# Test_1223: scab
# Test_1224: scab
# Test_1225: healthy
# Test_1226: rust
# Test_1227: scab
# Test_1228: rust
# Test_1229: rust
# Test_123: scab
# Test_1230: rust
# Test_1231: healthy
# Test_1232: rust
# Test_1233: scab
# Test_1234: healthy
# Test_1235: healthy
# Test_1236: healthy
# Test_1237: rust
# Test_1238: scab
# Test_1239: scab
# Test_124: healthy
# Test_1240: scab
# Test_1241: scab
# Test_1242: scab
# Test_1243: rust
# Test_1244: rust
# Test_1245: scab
# Test_1246: scab
# Test_1247: rust
# Test_1248: scab
# Test_1249: rust
# Test_125: rust
# Test_1250: healthy
# Test_1251: rust
# Test_1252: rust
# Test_1253: healthy
# Test_1254: healthy
# Test_1255: scab
# Test_1256: scab
# Test_1257: rust
# Test_1258: scab
# Test_1259: healthy
# Test_126: healthy
# Test_1260: healthy
# Test_1261: scab
# Test_1262: rust
# Test_1263: scab
# Test_1264: healthy
# Test_1265: scab
# Test_1266: rust
# Test_1267: healthy
# Test_1268: scab
# Test_1269: scab
# Test_127: healthy
# Test_1270: scab
# Test_1271: scab
# Test_1272: scab
# Test_1273: rust
# Test_1274: healthy
# Test_1275: scab
# Test_1276: scab
# Test_1277: scab
# Test_1278: healthy
# Test_1279: scab
# Test_128: rust
# Test_1280: rust
# Test_1281: scab
# Test_1282: scab
# Test_1283: scab
# Test_1284: rust
# Test_1285: scab
# Test_1286: rust
# Test_1287: rust
# Test_1288: healthy
# Test_1289: scab
# Test_129: healthy
# Test_1290: rust
# Test_1291: healthy
# Test_1292: healthy
# Test_1293: rust
# Test_1294: scab
# Test_1295: rust
# Test_1296: healthy
# Test_1297: scab
# Test_1298: rust
# Test_1299: scab
# Test_13: rust
# Test_130: scab
# Test_1300: healthy
# Test_1301: scab
# Test_1302: scab
# Test_1303: healthy
# Test_1304: rust
# Test_1305: scab
# Test_1306: scab
# Test_1307: scab
# Test_1308: scab
# Test_1309: scab
# Test_131: scab
# Test_1310: scab
# Test_1311: healthy
# Test_1312: scab
# Test_1313: rust
# Test_1314: scab
# Test_1315: healthy
# Test_1316: healthy
# Test_1317: scab
# Test_1318: healthy
# Test_1319: scab
# Test_132: healthy
# Test_1320: scab
# Test_1321: healthy
# Test_1322: healthy
# Test_1323: scab
# Test_1324: scab
# Test_1325: scab
# Test_1326: rust
# Test_1327: rust
# Test_1328: rust
# Test_1329: healthy
# Test_133: healthy
# Test_1330: rust
# Test_1331: rust
# Test_1332: scab
# Test_1333: healthy
# Test_1334: scab
# Test_1335: scab
# Test_1336: scab
# Test_1337: rust
# Test_1338: scab
# Test_1339: scab
# Test_134: healthy
# Test_1340: healthy
# Test_1341: rust
# Test_1342: rust
# Test_1343: scab
# Test_1344: rust
# Test_1345: healthy
# Test_1346: rust
# Test_1347: scab
# Test_1348: scab
# Test_1349: scab
# Test_135: rust
# Test_1350: rust
# Test_1351: rust
# Test_1352: scab
# Test_1353: rust
# Test_1354: scab
# Test_1355: rust
# Test_1356: scab
# Test_1357: scab
# Test_1358: scab
# Test_1359: rust
# Test_136: scab
# Test_1360: healthy
# Test_1361: scab
# Test_1362: scab
# Test_1363: scab
# Test_1364: rust
# Test_1365: healthy
# Test_1366: scab
# Test_1367: healthy
# Test_1368: scab
# Test_1369: rust
# Test_137: scab
# Test_1370: scab
# Test_1371: scab
# Test_1372: healthy
# Test_1373: rust
# Test_1374: scab
# Test_1375: rust
# Test_1376: rust
# Test_1377: healthy
# Test_1378: healthy
# Test_1379: scab
# Test_138: rust
# Test_1380: rust
# Test_1381: healthy
# Test_1382: rust
# Test_1383: scab
# Test_1384: healthy
# Test_1385: rust
# Test_1386: healthy
# Test_1387: scab
# Test_1388: healthy
# Test_1389: healthy
# Test_139: healthy
# Test_1390: healthy
# Test_1391: rust
# Test_1392: rust
# Test_1393: rust
# Test_1394: scab
# Test_1395: scab
# Test_1396: scab
# Test_1397: scab
# Test_1398: rust
# Test_1399: healthy
# Test_14: healthy
# Test_140: healthy
# Test_1400: scab
# Test_1401: scab
# Test_1402: scab
# Test_1403: scab
# Test_1404: healthy
# Test_1405: rust
# Test_1406: scab
# Test_1407: scab
# Test_1408: rust
# Test_1409: scab
# Test_141: scab
# Test_1410: scab
# Test_1411: rust
# Test_1412: rust
# Test_1413: scab
# Test_1414: healthy
# Test_1415: scab
# Test_1416: scab
# Test_1417: healthy
# Test_1418: rust
# Test_1419: scab
# Test_142: scab
# Test_1420: rust
# Test_1421: scab
# Test_1422: scab
# Test_1423: rust
# Test_1424: rust
# Test_1425: rust
# Test_1426: rust
# Test_1427: rust
# Test_1428: healthy
# Test_1429: scab
# Test_143: rust
# Test_1430: scab
# Test_1431: rust
# Test_1432: rust
# Test_1433: rust
# Test_1434: scab
# Test_1435: scab
# Test_1436: healthy
# Test_1437: scab
# Test_1438: healthy
# Test_1439: scab
# Test_144: healthy
# Test_1440: healthy
# Test_1441: scab
# Test_1442: scab
# Test_1443: scab
# Test_1444: rust
# Test_1445: healthy
# Test_1446: rust
# Test_1447: scab
# Test_1448: scab
# Test_1449: healthy
# Test_145: rust
# Test_1450: healthy
# Test_1451: scab
# Test_1452: scab
# Test_1453: healthy
# Test_1454: rust
# Test_1455: scab
# Test_1456: rust
# Test_1457: scab
# Test_1458: scab
# Test_1459: scab
# Test_146: scab
# Test_1460: rust
# Test_1461: rust
# Test_1462: rust
# Test_1463: rust
# Test_1464: scab
# Test_1465: rust
# Test_1466: healthy
# Test_1467: scab
# Test_1468: scab
# Test_1469: scab
# Test_147: scab
# Test_1470: scab
# Test_1471: scab
# Test_1472: healthy
# Test_1473: healthy
# Test_1474: scab
# Test_1475: scab
# Test_1476: scab
# Test_1477: scab
# Test_1478: healthy
# Test_1479: rust
# Test_148: healthy
# Test_1480: healthy
# Test_1481: rust
# Test_1482: rust
# Test_1483: scab
# Test_1484: healthy
# Test_1485: healthy
# Test_1486: scab
# Test_1487: scab
# Test_1488: scab
# Test_1489: healthy
# Test_149: healthy
# Test_1490: rust
# Test_1491: rust
# Test_1492: rust
# Test_1493: rust
# Test_1494: healthy
# Test_1495: healthy
# Test_1496: rust
# Test_1497: rust
# Test_1498: rust
# Test_1499: scab
# Test_15: healthy
# Test_150: healthy
# Test_1500: scab
# Test_1501: healthy
# Test_1502: scab
# Test_1503: healthy
# Test_1504: scab
# Test_1505: scab
# Test_1506: rust
# Test_1507: healthy
# Test_1508: rust
# Test_1509: rust
# Test_151: healthy
# Test_1510: scab
# Test_1511: scab
# Test_1512: rust
# Test_1513: rust
# Test_1514: rust
# Test_1515: rust
# Test_1516: healthy
# Test_1517: scab
# Test_1518: scab
# Test_1519: rust
# Test_152: scab
# Test_1520: rust
# Test_1521: rust
# Test_1522: scab
# Test_1523: rust
# Test_1524: healthy
# Test_1525: healthy
# Test_1526: healthy
# Test_1527: rust
# Test_1528: scab
# Test_1529: rust
# Test_153: scab
# Test_1530: healthy
# Test_1531: scab
# Test_1532: rust
# Test_1533: rust
# Test_1534: rust
# Test_1535: healthy
# Test_1536: healthy
# Test_1537: scab
# Test_1538: rust
# Test_1539: scab
# Test_154: rust
# Test_1540: rust
# Test_1541: healthy
# Test_1542: scab
# Test_1543: scab
# Test_1544: scab
# Test_1545: scab
# Test_1546: scab
# Test_1547: rust
# Test_1548: healthy
# Test_1549: scab
# Test_155: scab
# Test_1550: scab
# Test_1551: rust
# Test_1552: scab
# Test_1553: healthy
# Test_1554: scab
# Test_1555: scab
# Test_1556: rust
# Test_1557: scab
# Test_1558: scab
# Test_1559: rust
# Test_156: healthy
# Test_1560: rust
# Test_1561: rust
# Test_1562: healthy
# Test_1563: scab
# Test_1564: scab
# Test_1565: scab
# Test_1566: scab
# Test_1567: rust
# Test_1568: healthy
# Test_1569: healthy
# Test_157: scab
# Test_1570: rust
# Test_1571: scab
# Test_1572: scab
# Test_1573: scab
# Test_1574: healthy
# Test_1575: rust
# Test_1576: scab
# Test_1577: rust
# Test_1578: healthy
# Test_1579: rust
# Test_158: scab
# Test_1580: rust
# Test_1581: healthy
# Test_1582: scab
# Test_1583: rust
# Test_1584: scab
# Test_1585: scab
# Test_1586: healthy
# Test_1587: healthy
# Test_1588: healthy
# Test_1589: rust
# Test_159: rust
# Test_1590: rust
# Test_1591: scab
# Test_1592: rust
# Test_1593: healthy
# Test_1594: rust
# Test_1595: healthy
# Test_1596: rust
# Test_1597: rust
# Test_1598: scab
# Test_1599: scab
# Test_16: scab
# Test_160: rust
# Test_1600: healthy
# Test_1601: scab
# Test_1602: scab
# Test_1603: rust
# Test_1604: healthy
# Test_1605: rust
# Test_1606: healthy
# Test_1607: scab
# Test_1608: scab
# Test_1609: rust
# Test_161: rust
# Test_1610: scab
# Test_1611: rust
# Test_1612: scab
# Test_1613: scab
# Test_1614: healthy
# Test_1615: scab
# Test_1616: rust
# Test_1617: scab
# Test_1618: healthy
# Test_1619: scab
# Test_162: healthy
# Test_1620: rust
# Test_1621: scab
# Test_1622: scab
# Test_1623: scab
# Test_1624: scab
# Test_1625: rust
# Test_1626: rust
# Test_1627: scab
# Test_1628: healthy
# Test_1629: rust
# Test_163: scab
# Test_1630: scab
# Test_1631: rust
# Test_1632: healthy
# Test_1633: rust
# Test_1634: rust
# Test_1635: scab
# Test_1636: healthy
# Test_1637: scab
# Test_1638: rust
# Test_1639: rust
# Test_164: rust
# Test_1640: healthy
# Test_1641: healthy
# Test_1642: healthy
# Test_1643: healthy
# Test_1644: scab
# Test_1645: rust
# Test_1646: scab
# Test_1647: scab
# Test_1648: rust
# Test_1649: scab
# Test_165: rust
# Test_1650: scab
# Test_1651: healthy
# Test_1652: healthy
# Test_1653: healthy
# Test_1654: scab
# Test_1655: rust
# Test_1656: rust
# Test_1657: scab
# Test_1658: scab
# Test_1659: scab
# Test_166: rust
# Test_1660: scab
# Test_1661: healthy
# Test_1662: scab
# Test_1663: scab
# Test_1664: scab
# Test_1665: scab
# Test_1666: scab
# Test_1667: scab
# Test_1668: scab
# Test_1669: scab
# Test_167: scab
# Test_1670: scab
# Test_1671: healthy
# Test_1672: rust
# Test_1673: scab
# Test_1674: scab
# Test_1675: healthy
# Test_1676: healthy
# Test_1677: rust
# Test_1678: rust
# Test_1679: rust
# Test_168: scab
# Test_1680: healthy
# Test_1681: scab
# Test_1682: healthy
# Test_1683: scab
# Test_1684: rust
# Test_1685: rust
# Test_1686: healthy
# Test_1687: scab
# Test_1688: healthy
# Test_1689: rust
# Test_169: rust
# Test_1690: healthy
# Test_1691: rust
# Test_1692: healthy
# Test_1693: scab
# Test_1694: scab
# Test_1695: healthy
# Test_1696: scab
# Test_1697: scab
# Test_1698: scab
# Test_1699: scab
# Test_17: scab
# Test_170: scab
# Test_1700: scab
# Test_1701: scab
# Test_1702: healthy
# Test_1703: healthy
# Test_1704: healthy
# Test_1705: scab
# Test_1706: rust
# Test_1707: rust
# Test_1708: healthy
# Test_1709: scab
# Test_171: rust
# Test_1710: scab
# Test_1711: scab
# Test_1712: scab
# Test_1713: rust
# Test_1714: healthy
# Test_1715: scab
# Test_1716: scab
# Test_1717: rust
# Test_1718: scab
# Test_1719: rust
# Test_172: scab
# Test_1720: healthy
# Test_1721: rust
# Test_1722: rust
# Test_1723: healthy
# Test_1724: rust
# Test_1725: scab
# Test_1726: healthy
# Test_1727: healthy
# Test_1728: scab
# Test_1729: rust
# Test_173: rust
# Test_1730: healthy
# Test_1731: rust
# Test_1732: rust
# Test_1733: rust
# Test_1734: scab
# Test_1735: rust
# Test_1736: rust
# Test_1737: scab
# Test_1738: scab
# Test_1739: rust
# Test_174: rust
# Test_1740: scab
# Test_1741: healthy
# Test_1742: rust
# Test_1743: healthy
# Test_1744: healthy
# Test_1745: scab
# Test_1746: rust
# Test_1747: rust
# Test_1748: scab
# Test_1749: rust
# Test_175: rust
# Test_1750: rust
# Test_1751: scab
# Test_1752: scab
# Test_1753: rust
# Test_1754: scab
# Test_1755: scab
# Test_1756: rust
# Test_1757: scab
# Test_1758: rust
# Test_1759: scab
# Test_176: healthy
# Test_1760: rust
# Test_1761: rust
# Test_1762: scab
# Test_1763: scab
# Test_1764: scab
# Test_1765: scab
# Test_1766: healthy
# Test_1767: scab
# Test_1768: healthy
# Test_1769: healthy
# Test_177: scab
# Test_1770: rust
# Test_1771: rust
# Test_1772: scab
# Test_1773: rust
# Test_1774: rust
# Test_1775: scab
# Test_1776: scab
# Test_1777: healthy
# Test_1778: rust
# Test_1779: rust
# Test_178: scab
# Test_1780: scab
# Test_1781: scab
# Test_1782: healthy
# Test_1783: rust
# Test_1784: scab
# Test_1785: scab
# Test_1786: healthy
# Test_1787: scab
# Test_1788: scab
# Test_1789: rust
# Test_179: healthy
# Test_1790: scab
# Test_1791: scab
# Test_1792: healthy
# Test_1793: scab
# Test_1794: rust
# Test_1795: scab
# Test_1796: scab
# Test_1797: healthy
# Test_1798: rust
# Test_1799: scab
# Test_18: rust
# Test_180: scab
# Test_1800: healthy
# Test_1801: scab
# Test_1802: rust
# Test_1803: scab
# Test_1804: scab
# Test_1805: rust
# Test_1806: scab
# Test_1807: healthy
# Test_1808: rust
# Test_1809: rust
# Test_181: healthy
# Test_1810: rust
# Test_1811: scab
# Test_1812: scab
# Test_1813: scab
# Test_1814: scab
# Test_1815: rust
# Test_1816: scab
# Test_1817: scab
# Test_1818: scab
# Test_1819: healthy
# Test_182: healthy
# Test_1820: rust
# Test_183: scab
# Test_184: rust
# Test_185: healthy
# Test_186: rust
# Test_187: scab
# Test_188: rust
# Test_189: healthy
# Test_19: rust
# Test_190: rust
# Test_191: rust
# Test_192: scab
# Test_193: rust
# Test_194: rust
# Test_195: healthy
# Test_196: healthy
# Test_197: rust
# Test_198: rust
# Test_199: scab
# Test_2: scab
# Test_20: healthy
# Test_200: healthy
# Test_201: scab
# Test_202: scab
# Test_203: scab
# Test_204: rust
# Test_205: scab
# Test_206: rust
# Test_207: scab
# Test_208: healthy
# Test_209: healthy
# Test_21: rust
# Test_210: rust
# Test_211: rust
# Test_212: rust
# Test_213: scab
# Test_214: rust
# Test_215: rust
# Test_216: rust
# Test_217: scab
# Test_218: healthy
# Test_219: rust
# Test_22: scab
# Test_220: scab
# Test_221: scab
# Test_222: healthy
# Test_223: scab
# Test_224: rust
# Test_225: rust
# Test_226: scab
# Test_227: rust
# Test_228: rust
# Test_229: scab
# Test_23: scab
# Test_230: scab
# Test_231: rust
# Test_232: healthy
# Test_233: scab
# Test_234: scab
# Test_235: scab
# Test_236: rust
# Test_237: scab
# Test_238: rust
# Test_239: rust
# Test_24: rust
# Test_240: scab
# Test_241: scab
# Test_242: healthy
# Test_243: scab
# Test_244: scab
# Test_245: scab
# Test_246: scab
# Test_247: scab
# Test_248: healthy
# Test_249: rust
# Test_25: rust
# Test_250: rust
# Test_251: scab
# Test_252: rust
# Test_253: rust
# Test_254: scab
# Test_255: scab
# Test_256: healthy
# Test_257: scab
# Test_258: scab
# Test_259: rust
# Test_26: scab
# Test_260: scab
# Test_261: scab
# Test_262: healthy
# Test_263: healthy
# Test_264: rust
# Test_265: scab
# Test_266: scab
# Test_267: healthy
# Test_268: rust
# Test_269: rust
# Test_27: rust
# Test_270: scab
# Test_271: healthy
# Test_272: scab
# Test_273: rust
# Test_274: healthy
# Test_275: rust
# Test_276: rust
# Test_277: rust
# Test_278: scab
# Test_279: rust
# Test_28: healthy
# Test_280: scab
# Test_281: scab
# Test_282: scab
# Test_283: rust
# Test_284: rust
# Test_285: rust
# Test_286: scab
# Test_287: rust
# Test_288: scab
# Test_289: scab
# Test_29: rust
# Test_290: scab
# Test_291: scab
# Test_292: healthy
# Test_293: scab
# Test_294: healthy
# Test_295: healthy
# Test_296: scab
# Test_297: scab
# Test_298: scab
# Test_299: scab
# Test_3: scab
# Test_30: healthy
# Test_300: scab
# Test_301: scab
# Test_302: rust
# Test_303: scab
# Test_304: healthy
# Test_305: scab
# Test_306: scab
# Test_307: healthy
# Test_308: scab
# Test_309: scab
# Test_31: scab
# Test_310: scab
# Test_311: healthy
# Test_312: scab
# Test_313: rust
# Test_314: scab
# Test_315: rust
# Test_316: healthy
# Test_317: scab
# Test_318: scab
# Test_319: rust
# Test_32: scab
# Test_320: rust
# Test_321: rust
# Test_322: healthy
# Test_323: healthy
# Test_324: rust
# Test_325: healthy
# Test_326: scab
# Test_327: scab
# Test_328: scab
# Test_329: scab
# Test_33: scab
# Test_330: rust
# Test_331: scab
# Test_332: healthy
# Test_333: healthy
# Test_334: rust
# Test_335: scab
# Test_336: rust
# Test_337: rust
# Test_338: healthy
# Test_339: scab
# Test_34: scab
# Test_340: rust
# Test_341: healthy
# Test_342: scab
# Test_343: scab
# Test_344: scab
# Test_345: scab
# Test_346: healthy
# Test_347: healthy
# Test_348: scab
# Test_349: rust
# Test_35: scab
# Test_350: scab
# Test_351: rust
# Test_352: healthy
# Test_353: scab
# Test_354: healthy
# Test_355: healthy
# Test_356: healthy
# Test_357: scab
# Test_358: scab
# Test_359: scab
# Test_36: rust
# Test_360: scab
# Test_361: healthy
# Test_362: rust
# Test_363: scab
# Test_364: rust
# Test_365: healthy
# Test_366: healthy
# Test_367: scab
# Test_368: rust
# Test_369: scab
# Test_37: scab
# Test_370: scab
# Test_371: rust
# Test_372: rust
# Test_373: rust
# Test_374: healthy
# Test_375: scab
# Test_376: healthy
# Test_377: rust
# Test_378: rust
# Test_379: scab
# Test_38: rust
# Test_380: healthy
# Test_381: scab
# Test_382: scab
# Test_383: rust
# Test_384: healthy
# Test_385: scab
# Test_386: healthy
# Test_387: scab
# Test_388: healthy
# Test_389: healthy
# Test_39: rust
# Test_390: scab
# Test_391: scab
# Test_392: scab
# Test_393: scab
# Test_394: scab
# Test_395: rust
# Test_396: scab
# Test_397: rust
# Test_398: scab
# Test_399: scab
# Test_4: scab
# Test_40: scab
# Test_400: rust
# Test_401: healthy
# Test_402: scab
# Test_403: rust
# Test_404: rust
# Test_405: scab
# Test_406: scab
# Test_407: scab
# Test_408: scab
# Test_409: scab
# Test_41: scab
# Test_410: scab
# Test_411: rust
# Test_412: rust
# Test_413: healthy
# Test_414: rust
# Test_415: rust
# Test_416: scab
# Test_417: healthy
# Test_418: healthy
# Test_419: healthy
# Test_42: scab
# Test_420: scab
# Test_421: rust
# Test_422: healthy
# Test_423: scab
# Test_424: rust
# Test_425: scab
# Test_426: healthy
# Test_427: rust
# Test_428: scab
# Test_429: rust
# Test_43: healthy
# Test_430: healthy
# Test_431: healthy
# Test_432: healthy
# Test_433: scab
# Test_434: scab
# Test_435: scab
# Test_436: scab
# Test_437: healthy
# Test_438: scab
# Test_439: rust
# Test_44: scab
# Test_440: scab
# Test_441: healthy
# Test_442: rust
# Test_443: rust
# Test_444: scab
# Test_445: scab
# Test_446: rust
# Test_447: rust
# Test_448: rust
# Test_449: rust
# Test_45: scab
# Test_450: healthy
# Test_451: scab
# Test_452: scab
# Test_453: scab
# Test_454: scab
# Test_455: scab
# Test_456: scab
# Test_457: scab
# Test_458: scab
# Test_459: healthy
# Test_46: scab
# Test_460: scab
# Test_461: healthy
# Test_462: rust
# Test_463: healthy
# Test_464: rust
# Test_465: rust
# Test_466: scab
# Test_467: rust
# Test_468: rust
# Test_469: rust
# Test_47: rust
# Test_470: rust
# Test_471: rust
# Test_472: rust
# Test_473: scab
# Test_474: scab
# Test_475: rust
# Test_476: scab
# Test_477: scab
# Test_478: scab
# Test_479: rust
# Test_48: rust
# Test_480: rust
# Test_481: healthy
# Test_482: healthy
# Test_483: rust
# Test_484: rust
# Test_485: rust
# Test_486: scab
# Test_487: healthy
# Test_488: scab
# Test_489: rust
# Test_49: healthy
# Test_490: scab
# Test_491: healthy
# Test_492: scab
# Test_493: scab
# Test_494: scab
# Test_495: scab
# Test_496: rust
# Test_497: scab
# Test_498: scab
# Test_499: scab
# Test_5: healthy
# Test_50: scab
# Test_500: healthy
# Test_501: scab
# Test_502: healthy
# Test_503: healthy
# Test_504: scab
# Test_505: scab
# Test_506: scab
# Test_507: scab
# Test_508: rust
# Test_509: rust
# Test_51: rust
# Test_510: scab
# Test_511: scab
# Test_512: healthy
# Test_513: scab
# Test_514: rust
# Test_515: healthy
# Test_516: rust
# Test_517: rust
# Test_518: scab
# Test_519: healthy
# Test_52: rust
# Test_520: rust
# Test_521: scab
# Test_522: scab
# Test_523: scab
# Test_524: rust
# Test_525: rust
# Test_526: scab
# Test_527: rust
# Test_528: healthy
# Test_529: healthy
# Test_53: rust
# Test_530: rust
# Test_531: rust
# Test_532: scab
# Test_533: rust
# Test_534: scab
# Test_535: scab
# Test_536: healthy
# Test_537: healthy
# Test_538: scab
# Test_539: scab
# Test_54: healthy
# Test_540: scab
# Test_541: scab
# Test_542: healthy
# Test_543: healthy
# Test_544: scab
# Test_545: scab
# Test_546: scab
# Test_547: rust
# Test_548: scab
# Test_549: scab
# Test_55: healthy
# Test_550: scab
# Test_551: rust
# Test_552: scab
# Test_553: rust
# Test_554: scab
# Test_555: healthy
# Test_556: scab
# Test_557: rust
# Test_558: scab
# Test_559: healthy
# Test_56: scab
# Test_560: rust
# Test_561: healthy
# Test_562: healthy
# Test_563: rust
# Test_564: rust
# Test_565: scab
# Test_566: scab
# Test_567: scab
# Test_568: scab
# Test_569: scab
# Test_57: healthy
# Test_570: rust
# Test_571: scab
# Test_572: rust
# Test_573: rust
# Test_574: rust
# Test_575: scab
# Test_576: scab
# Test_577: rust
# Test_578: rust
# Test_579: healthy
# Test_58: scab
# Test_580: rust
# Test_581: healthy
# Test_582: scab
# Test_583: rust
# Test_584: rust
# Test_585: healthy
# Test_586: scab
# Test_587: rust
# Test_588: healthy
# Test_589: healthy
# Test_59: healthy
# Test_590: scab
# Test_591: healthy
# Test_592: rust
# Test_593: scab
# Test_594: rust
# Test_595: scab
# Test_596: scab
# Test_597: scab
# Test_598: scab
# Test_599: scab
# Test_6: scab
# Test_60: scab
# Test_600: scab
# Test_601: rust
# Test_602: scab
# Test_603: scab
# Test_604: healthy
# Test_605: scab
# Test_606: scab
# Test_607: scab
# Test_608: rust
# Test_609: scab
# Test_61: rust
# Test_610: rust
# Test_611: rust
# Test_612: scab
# Test_613: scab
# Test_614: scab
# Test_615: scab
# Test_616: scab
# Test_617: healthy
# Test_618: scab
# Test_619: scab
# Test_62: rust
# Test_620: scab
# Test_621: healthy
# Test_622: scab
# Test_623: rust
# Test_624: scab
# Test_625: rust
# Test_626: rust
# Test_627: healthy
# Test_628: scab
# Test_629: healthy
# Test_63: rust
# Test_630: healthy
# Test_631: scab
# Test_632: rust
# Test_633: healthy
# Test_634: scab
# Test_635: rust
# Test_636: rust
# Test_637: rust
# Test_638: healthy
# Test_639: healthy
# Test_64: rust
# Test_640: scab
# Test_641: healthy
# Test_642: scab
# Test_643: rust
# Test_644: scab
# Test_645: rust
# Test_646: scab
# Test_647: rust
# Test_648: rust
# Test_649: rust
# Test_65: scab
# Test_650: scab
# Test_651: scab
# Test_652: scab
# Test_653: healthy
# Test_654: healthy
# Test_655: rust
# Test_656: rust
# Test_657: rust
# Test_658: scab
# Test_659: rust
# Test_66: rust
# Test_660: scab
# Test_661: rust
# Test_662: scab
# Test_663: scab
# Test_664: healthy
# Test_665: rust
# Test_666: scab
# Test_667: rust
# Test_668: rust
# Test_669: scab
# Test_67: rust
# Test_670: scab
# Test_671: rust
# Test_672: healthy
# Test_673: rust
# Test_674: rust
# Test_675: rust
# Test_676: rust
# Test_677: scab
# Test_678: rust
# Test_679: rust
# Test_68: rust
# Test_680: scab
# Test_681: scab
# Test_682: healthy
# Test_683: rust
# Test_684: scab
# Test_685: healthy
# Test_686: scab
# Test_687: rust
# Test_688: scab
# Test_689: rust
# Test_69: scab
# Test_690: rust
# Test_691: scab
# Test_692: scab
# Test_693: healthy
# Test_694: scab
# Test_695: healthy
# Test_696: rust
# Test_697: scab
# Test_698: rust
# Test_699: scab
# Test_7: scab
# Test_70: scab
# Test_700: rust
# Test_701: healthy
# Test_702: scab
# Test_703: rust
# Test_704: rust
# Test_705: scab
# Test_706: rust
# Test_707: scab
# Test_708: healthy
# Test_709: healthy
# Test_71: rust
# Test_710: scab
# Test_711: healthy
# Test_712: scab
# Test_713: scab
# Test_714: scab
# Test_715: rust
# Test_716: rust
# Test_717: rust
# Test_718: scab
# Test_719: rust
# Test_72: rust
# Test_720: scab
# Test_721: healthy
# Test_722: scab
# Test_723: healthy
# Test_724: healthy
# Test_725: scab
# Test_726: rust
# Test_727: healthy
# Test_728: scab
# Test_729: healthy
# Test_73: rust
# Test_730: rust
# Test_731: scab
# Test_732: scab
# Test_733: scab
# Test_734: scab
# Test_735: healthy
# Test_736: healthy
# Test_737: scab
# Test_738: healthy
# Test_739: rust
# Test_74: healthy
# Test_740: scab
# Test_741: scab
# Test_742: healthy
# Test_743: scab
# Test_744: rust
# Test_745: rust
# Test_746: healthy
# Test_747: healthy
# Test_748: rust
# Test_749: scab
# Test_75: scab
# Test_750: scab
# Test_751: rust
# Test_752: scab
# Test_753: scab
# Test_754: scab
# Test_755: rust
# Test_756: rust
# Test_757: scab
# Test_758: rust
# Test_759: scab
# Test_76: healthy
# Test_760: healthy
# Test_761: rust
# Test_762: healthy
# Test_763: rust
# Test_764: healthy
# Test_765: scab
# Test_766: rust
# Test_767: scab
# Test_768: healthy
# Test_769: scab
# Test_77: scab
# Test_770: healthy
# Test_771: rust
# Test_772: healthy
# Test_773: scab
# Test_774: rust
# Test_775: scab
# Test_776: healthy
# Test_777: rust
# Test_778: healthy
# Test_779: rust
# Test_78: scab
# Test_780: scab
# Test_781: scab
# Test_782: scab
# Test_783: scab
# Test_784: rust
# Test_785: scab
# Test_786: scab
# Test_787: rust
# Test_788: rust
# Test_789: scab
# Test_79: healthy
# Test_790: rust
# Test_791: rust
# Test_792: rust
# Test_793: scab
# Test_794: rust
# Test_795: healthy
# Test_796: rust
# Test_797: healthy
# Test_798: rust
# Test_799: healthy
# Test_8: scab
# Test_80: scab
# Test_800: scab
# Test_801: rust
# Test_802: scab
# Test_803: scab
# Test_804: scab
# Test_805: rust
# Test_806: rust
# Test_807: rust
# Test_808: rust
# Test_809: scab
# Test_81: scab
# Test_810: rust
# Test_811: healthy
# Test_812: healthy
# Test_813: healthy
# Test_814: scab
# Test_815: rust
# Test_816: scab
# Test_817: scab
# Test_818: rust
# Test_819: rust
# Test_82: healthy
# Test_820: rust
# Test_821: scab
# Test_822: rust
# Test_823: rust
# Test_824: rust
# Test_825: scab
# Test_826: healthy
# Test_827: healthy
# Test_828: scab
# Test_829: scab
# Test_83: scab
# Test_830: healthy
# Test_831: scab
# Test_832: rust
# Test_833: rust
# Test_834: healthy
# Test_835: healthy
# Test_836: scab
# Test_837: scab
# Test_838: scab
# Test_839: scab
# Test_84: rust
# Test_840: rust
# Test_841: scab
# Test_842: healthy
# Test_843: rust
# Test_844: scab
# Test_845: rust
# Test_846: rust
# Test_847: scab
# Test_848: healthy
# Test_849: rust
# Test_85: rust
# Test_850: rust
# Test_851: healthy
# Test_852: rust
# Test_853: scab
# Test_854: rust
# Test_855: rust
# Test_856: scab
# Test_857: rust
# Test_858: scab
# Test_859: scab
# Test_86: scab
# Test_860: scab
# Test_861: rust
# Test_862: scab
# Test_863: scab
# Test_864: healthy
# Test_865: rust
# Test_866: healthy
# Test_867: scab
# Test_868: scab
# Test_869: healthy
# Test_87: scab
# Test_870: healthy
# Test_871: scab
# Test_872: rust
# Test_873: scab
# Test_874: healthy
# Test_875: scab
# Test_876: healthy
# Test_877: scab
# Test_878: rust
# Test_879: healthy
# Test_88: healthy
# Test_880: scab
# Test_881: scab
# Test_882: scab
# Test_883: scab
# Test_884: healthy
# Test_885: healthy
# Test_886: healthy
# Test_887: healthy
# Test_888: scab
# Test_889: healthy
# Test_89: scab
# Test_890: rust
# Test_891: rust
# Test_892: healthy
# Test_893: healthy
# Test_894: scab
# Test_895: rust
# Test_896: healthy
# Test_897: healthy
# Test_898: healthy
# Test_899: healthy
# Test_9: rust
# Test_90: rust
# Test_900: rust
# Test_901: healthy
# Test_902: healthy
# Test_903: rust
# Test_904: rust
# Test_905: scab
# Test_906: rust
# Test_907: rust
# Test_908: scab
# Test_909: healthy
# Test_91: scab
# Test_910: scab
# Test_911: scab
# Test_912: rust
# Test_913: rust
# Test_914: rust
# Test_915: rust
# Test_916: scab
# Test_917: scab
# Test_918: scab
# Test_919: scab
# Test_92: rust
# Test_920: rust
# Test_921: rust
# Test_922: rust
# Test_923: healthy
# Test_924: healthy
# Test_925: rust
# Test_926: healthy
# Test_927: scab
# Test_928: healthy
# Test_929: rust
# Test_93: rust
# Test_930: healthy
# Test_931: rust
# Test_932: scab
# Test_933: rust
# Test_934: healthy
# Test_935: scab
# Test_936: scab
# Test_937: healthy
# Test_938: scab
# Test_939: rust
# Test_94: scab
# Test_940: scab
# Test_941: scab
# Test_942: rust
# Test_943: rust
# Test_944: rust
# Test_945: scab
# Test_946: scab
# Test_947: rust
# Test_948: rust
# Test_949: healthy
# Test_95: rust
# Test_950: rust
# Test_951: scab
# Test_952: scab
# Test_953: scab
# Test_954: scab
# Test_955: healthy
# Test_956: scab
# Test_957: rust
# Test_958: scab
# Test_959: healthy
# Test_96: rust
# Test_960: rust
# Test_961: scab
# Test_962: healthy
# Test_963: healthy
# Test_964: healthy
# Test_965: rust
# Test_966: rust
# Test_967: rust
# Test_968: rust
# Test_969: scab
# Test_97: rust
# Test_970: healthy
# Test_971: scab
# Test_972: healthy
# Test_973: scab
# Test_974: scab
# Test_975: healthy
# Test_976: scab
# Test_977: healthy
# Test_978: rust
# Test_979: healthy
# Test_98: healthy
# Test_980: rust
# Test_981: scab
# Test_982: rust
# Test_983: scab
# Test_984: rust
# Test_985: rust
# Test_986: scab
# Test_987: rust
# Test_988: healthy
# Test_989: healthy
# Test_99: rust
# Test_990: healthy
# Test_991: scab
# Test_992: rust
# Test_993: rust
# Test_994: scab
# Test_995: rust
# Test_996: rust
# Test_997: healthy
# Test_998: rust
# Test_999: healthy
# Train_0: scab
# Train_1: rust
# Train_10: rust
# Train_100: healthy
# Train_1000: rust
# Train_1001: healthy
# Train_1002: healthy
# Train_1003: scab
# Train_1004: healthy
# Train_1005: healthy
# Train_1006: scab
# Train_1007: healthy
# Train_1008: scab
# Train_1009: scab
# Train_101: scab
# Train_1010: scab
# Train_1011: rust
# Train_1012: healthy
# Train_1013: multiple_diseases
# Train_1014: healthy
# Train_1015: scab
# Train_1016: scab
# Train_1017: healthy
# Train_1018: healthy
# Train_1019: rust
# Train_102: rust
# Train_1020: healthy
# Train_1021: rust
# Train_1022: rust
# Train_1023: rust
# Train_1024: scab
# Train_1025: scab
# Train_1026: scab
# Train_1027: scab
# Train_1028: scab
# Train_1029: rust
# Train_103: healthy
# Train_1030: rust
# Train_1031: rust
# Train_1032: scab
# Train_1033: scab
# Train_1034: healthy
# Train_1035: rust
# Train_1036: scab
# Train_1037: scab
# Train_1038: scab
# Train_1039: healthy
# Train_104: rust
# Train_1040: rust
# Train_1041: rust
# Train_1042: scab
# Train_1043: healthy
# Train_1044: healthy
# Train_1045: scab
# Train_1046: scab
# Train_1047: healthy
# Train_1048: rust
# Train_1049: scab
# Train_105: healthy
# Train_1050: scab
# Train_1051: rust
# Train_1052: scab
# Train_1053: rust
# Train_1054: healthy
# Train_1055: healthy
# Train_1056: scab
# Train_1057: rust
# Train_1058: scab
# Train_1059: scab
# Train_106: scab
# Train_1060: rust
# Train_1061: scab
# Train_1062: rust
# Train_1063: rust
# Train_1064: rust
# Train_1065: scab
# Train_1066: healthy
# Train_1067: healthy
# Train_1068: scab
# Train_1069: rust
# Train_107: scab
# Train_1070: rust
# Train_1071: rust
# Train_1072: healthy
# Train_1073: rust
# Train_1074: scab
# Train_1075: scab
# Train_1076: scab
# Train_1077: scab
# Train_1078: rust
# Train_1079: healthy
# Train_108: rust
# Train_1080: healthy
# Train_1081: rust
# Train_1082: rust
# Train_1083: scab
# Train_1084: rust
# Train_1085: healthy
# Train_1086: healthy
# Train_1087: rust
# Train_1088: scab
# Train_1089: scab
# Train_109: rust
# Train_1090: scab
# Train_1091: healthy
# Train_1092: healthy
# Train_1093: rust
# Train_1094: scab
# Train_1095: scab
# Train_1096: rust
# Train_1097: healthy
# Train_1098: scab
# Train_1099: scab
# Train_11: scab
# Train_110: scab
# Train_1100: scab
# Train_1101: healthy
# Train_1102: rust
# Train_1103: healthy
# Train_1104: scab
# Train_1105: rust
# Train_1106: scab
# Train_1107: scab
# Train_1108: rust
# Train_1109: scab
# Train_111: healthy
# Train_1110: healthy
# Train_1111: rust
# Train_1112: rust
# Train_1113: rust
# Train_1114: healthy
# Train_1115: healthy
# Train_1116: rust
# Train_1117: healthy
# Train_1118: rust
# Train_1119: scab
# Train_112: scab
# Train_1120: scab
# Train_1121: rust
# Train_1122: rust
# Train_1123: healthy
# Train_1124: scab
# Train_1125: rust
# Train_1126: rust
# Train_1127: scab
# Train_1128: scab
# Train_1129: rust
# Train_113: scab
# Train_1130: rust
# Train_1131: healthy
# Train_1132: scab
# Train_1133: healthy
# Train_1134: scab
# Train_1135: scab
# Train_1136: scab
# Train_1137: scab
# Train_1138: healthy
# Train_1139: healthy
# Train_114: rust
# Train_1140: scab
# Train_1141: healthy
# Train_1142: rust
# Train_1143: scab
# Train_1144: rust
# Train_1145: rust
# Train_1146: healthy
# Train_1147: rust
# Train_1148: rust
# Train_1149: rust
# Train_115: rust
# Train_1150: rust
# Train_1151: healthy
# Train_1152: scab
# Train_1153: rust
# Train_1154: healthy
# Train_1155: scab
# Train_1156: rust
# Train_1157: scab
# Train_1158: rust
# Train_1159: healthy
# Train_116: scab
# Train_1160: healthy
# Train_1161: scab
# Train_1162: scab
# Train_1163: rust
# Train_1164: healthy
# Train_1165: rust
# Train_1166: scab
# Train_1167: scab
# Train_1168: scab
# Train_1169: rust
# Train_117: rust
# Train_1170: rust
# Train_1171: healthy
# Train_1172: scab
# Train_1173: multiple_diseases
# Train_1174: scab
# Train_1175: rust
# Train_1176: healthy
# Train_1177: rust
# Train_1178: scab
# Train_1179: rust
# Train_118: rust
# Train_1180: healthy
# Train_1181: scab
# Train_1182: rust
# Train_1183: scab
# Train_1184: rust
# Train_1185: rust
# Train_1186: healthy
# Train_1187: rust
# Train_1188: scab
# Train_1189: rust
# Train_119: rust
# Train_1190: scab
# Train_1191: rust
# Train_1192: scab
# Train_1193: healthy
# Train_1194: rust
# Train_1195: healthy
# Train_1196: rust
# Train_1197: rust
# Train_1198: healthy
# Train_1199: healthy
# Train_12: scab
# Train_120: rust
# Train_1200: healthy
# Train_1201: scab
# Train_1202: scab
# Train_1203: scab
# Train_1204: rust
# Train_1205: rust
# Train_1206: rust
# Train_1207: rust
# Train_1208: scab
# Train_1209: scab
# Train_121: rust
# Train_1210: healthy
# Train_1211: scab
# Train_1212: scab
# Train_1213: rust
# Train_1214: healthy
# Train_1215: rust
# Train_1216: scab
# Train_1217: scab
# Train_1218: scab
# Train_1219: healthy
# Train_122: scab
# Train_1220: rust
# Train_1221: scab
# Train_1222: rust
# Train_1223: healthy
# Train_1224: scab
# Train_1225: rust
# Train_1226: scab
# Train_1227: scab
# Train_1228: scab
# Train_1229: rust
# Train_123: healthy
# Train_1230: healthy
# Train_1231: rust
# Train_1232: scab
# Train_1233: rust
# Train_1234: rust
# Train_1235: rust
# Train_1236: scab
# Train_1237: healthy
# Train_1238: scab
# Train_1239: healthy
# Train_124: rust
# Train_1240: healthy
# Train_1241: scab
# Train_1242: scab
# Train_1243: scab
# Train_1244: rust
# Train_1245: healthy
# Train_1246: scab
# Train_1247: healthy
# Train_1248: healthy
# Train_1249: scab
# Train_125: scab
# Train_1250: scab
# Train_1251: healthy
# Train_1252: scab
# Train_1253: rust
# Train_1254: healthy
# Train_1255: rust
# Train_1256: rust
# Train_1257: healthy
# Train_1258: scab
# Train_1259: scab
# Train_126: rust
# Train_1260: rust
# Train_1261: healthy
# Train_1262: rust
# Train_1263: rust
# Train_1264: scab
# Train_1265: healthy
# Train_1266: rust
# Train_1267: rust
# Train_1268: rust
# Train_1269: scab
# Train_127: scab
# Train_1270: healthy
# Train_1271: healthy
# Train_1272: rust
# Train_1273: scab
# Train_1274: scab
# Train_1275: rust
# Train_1276: scab
# Train_1277: healthy
# Train_1278: scab
# Train_1279: scab
# Train_128: multiple_diseases
# Train_1280: multiple_diseases
# Train_1281: scab
# Train_1282: rust
# Train_1283: rust
# Train_1284: rust
# Train_1285: healthy
# Train_1286: healthy
# Train_1287: healthy
# Train_1288: scab
# Train_1289: scab
# Train_129: rust
# Train_1290: healthy
# Train_1291: rust
# Train_1292: rust
# Train_1293: scab
# Train_1294: scab
# Train_1295: scab
# Train_1296: scab
# Train_1297: healthy
# Train_1298: scab
# Train_1299: rust
# Train_13: healthy
# Train_130: scab
# Train_1300: healthy
# Train_1301: scab
# Train_1302: rust
# Train_1303: scab
# Train_1304: healthy
# Train_1305: scab
# Train_1306: healthy
# Train_1307: rust
# Train_1308: scab
# Train_1309: rust
# Train_131: rust
# Train_1310: scab
# Train_1311: rust
# Train_1312: scab
# Train_1313: healthy
# Train_1314: scab
# Train_1315: scab
# Train_1316: rust
# Train_1317: scab
# Train_1318: rust
# Train_1319: rust
# Train_132: rust
# Train_1320: rust
# Train_1321: rust
# Train_1322: rust
# Train_1323: scab
# Train_1324: rust
# Train_1325: healthy
# Train_1326: rust
# Train_1327: rust
# Train_1328: healthy
# Train_1329: scab
# Train_133: rust
# Train_1330: rust
# Train_1331: scab
# Train_1332: rust
# Train_1333: rust
# Train_1334: rust
# Train_1335: healthy
# Train_1336: scab
# Train_1337: scab
# Train_1338: scab
# Train_1339: scab
# Train_134: healthy
# Train_1340: rust
# Train_1341: healthy
# Train_1342: rust
# Train_1343: scab
# Train_1344: rust
# Train_1345: scab
# Train_1346: scab
# Train_1347: healthy
# Train_1348: healthy
# Train_1349: healthy
# Train_135: healthy
# Train_1350: scab
# Train_1351: rust
# Train_1352: rust
# Train_1353: healthy
# Train_1354: healthy
# Train_1355: healthy
# Train_1356: healthy
# Train_1357: healthy
# Train_1358: multiple_diseases
# Train_1359: rust
# Train_136: healthy
# Train_1360: scab
# Train_1361: scab
# Train_1362: scab
# Train_1363: scab
# Train_1364: rust
# Train_1365: rust
# Train_1366: healthy
# Train_1367: scab
# Train_1368: healthy
# Train_1369: scab
# Train_137: healthy
# Train_1370: scab
# Train_1371: healthy
# Train_1372: healthy
# Train_1373: rust
# Train_1374: rust
# Train_1375: scab
# Train_1376: rust
# Train_1377: healthy
# Train_1378: scab
# Train_1379: rust
# Train_138: healthy
# Train_1380: scab
# Train_1381: healthy
# Train_1382: scab
# Train_1383: scab
# Train_1384: scab
# Train_1385: scab
# Train_1386: rust
# Train_1387: rust
# Train_1388: healthy
# Train_1389: healthy
# Train_139: rust
# Train_1390: healthy
# Train_1391: healthy
# Train_1392: healthy
# Train_1393: scab
# Train_1394: rust
# Train_1395: scab
# Train_1396: healthy
# Train_1397: healthy
# Train_1398: rust
# Train_1399: rust
# Train_14: rust
# Train_140: scab
# Train_1400: rust
# Train_1401: scab
# Train_1402: healthy
# Train_1403: scab
# Train_1404: rust
# Train_1405: scab
# Train_1406: rust
# Train_1407: rust
# Train_1408: healthy
# Train_1409: rust
# Train_141: rust
# Train_1410: scab
# Train_1411: scab
# Train_1412: rust
# Train_1413: rust
# Train_1414: healthy
# Train_1415: healthy
# Train_1416: scab
# Train_1417: healthy
# Train_1418: rust
# Train_1419: rust
# Train_142: scab
# Train_1420: healthy
# Train_1421: scab
# Train_1422: rust
# Train_1423: healthy
# Train_1424: healthy
# Train_1425: rust
# Train_1426: healthy
# Train_1427: rust
# Train_1428: rust
# Train_1429: scab
# Train_143: scab
# Train_1430: scab
# Train_1431: scab
# Train_1432: healthy
# Train_1433: multiple_diseases
# Train_1434: rust
# Train_1435: scab
# Train_1436: scab
# Train_1437: rust
# Train_1438: healthy
# Train_1439: rust
# Train_144: healthy
# Train_1440: healthy
# Train_1441: rust
# Train_1442: healthy
# Train_1443: rust
# Train_1444: scab
# Train_1445: scab
# Train_1446: rust
# Train_1447: healthy
# Train_1448: scab
# Train_1449: healthy
# Train_145: scab
# Train_1450: scab
# Train_1451: rust
# Train_1452: scab
# Train_1453: rust
# Train_1454: scab
# Train_1455: rust
# Train_1456: scab
# Train_1457: healthy
# Train_1458: rust
# Train_1459: healthy
# Train_146: healthy
# Train_1460: scab
# Train_1461: rust
# Train_1462: healthy
# Train_1463: healthy
# Train_1464: scab
# Train_1465: rust
# Train_1466: healthy
# Train_1467: rust
# Train_1468: scab
# Train_1469: rust
# Train_147: scab
# Train_1470: scab
# Train_1471: rust
# Train_1472: rust
# Train_1473: scab
# Train_1474: healthy
# Train_1475: rust
# Train_1476: healthy
# Train_1477: scab
# Train_1478: healthy
# Train_1479: healthy
# Train_148: rust
# Train_1480: rust
# Train_1481: scab
# Train_1482: healthy
# Train_1483: scab
# Train_1484: rust
# Train_1485: rust
# Train_1486: rust
# Train_1487: rust
# Train_1488: scab
# Train_1489: healthy
# Train_149: scab
# Train_1490: rust
# Train_1491: rust
# Train_1492: rust
# Train_1493: scab
# Train_1494: scab
# Train_1495: rust
# Train_1496: healthy
# Train_1497: rust
# Train_1498: scab
# Train_1499: scab
# Train_15: rust
# Train_150: healthy
# Train_1500: scab
# Train_1501: scab
# Train_1502: rust
# Train_1503: scab
# Train_1504: healthy
# Train_1505: scab
# Train_1506: scab
# Train_1507: scab
# Train_1508: healthy
# Train_1509: rust
# Train_151: healthy
# Train_1510: rust
# Train_1511: rust
# Train_1512: rust
# Train_1513: healthy
# Train_1514: scab
# Train_1515: rust
# Train_1516: rust
# Train_1517: healthy
# Train_1518: scab
# Train_1519: healthy
# Train_152: rust
# Train_1520: scab
# Train_1521: scab
# Train_1522: rust
# Train_1523: scab
# Train_1524: rust
# Train_1525: rust
# Train_1526: healthy
# Train_1527: rust
# Train_1528: healthy
# Train_1529: scab
# Train_153: scab
# Train_1530: healthy
# Train_1531: healthy
# Train_1532: scab
# Train_1533: healthy
# Train_1534: scab
# Train_1535: rust
# Train_1536: scab
# Train_1537: scab
# Train_1538: rust
# Train_1539: healthy
# Train_154: scab
# Train_1540: rust
# Train_1541: healthy
# Train_1542: scab
# Train_1543: scab
# Train_1544: rust
# Train_1545: scab
# Train_1546: healthy
# Train_1547: rust
# Train_1548: healthy
# Train_1549: healthy
# Train_155: scab
# Train_1550: scab
# Train_1551: rust
# Train_1552: healthy
# Train_1553: scab
# Train_1554: rust
# Train_1555: healthy
# Train_1556: rust
# Train_1557: healthy
# Train_1558: multiple_diseases
# Train_1559: healthy
# Train_156: rust
# Train_1560: rust
# Train_1561: rust
# Train_1562: healthy
# Train_1563: healthy
# Train_1564: healthy
# Train_1565: rust
# Train_1566: scab
# Train_1567: rust
# Train_1568: scab
# Train_1569: rust
# Train_157: rust
# Train_1570: scab
# Train_1571: scab
# Train_1572: scab
# Train_1573: rust
# Train_1574: rust
# Train_1575: healthy
# Train_1576: rust
# Train_1577: rust
# Train_1578: rust
# Train_1579: rust
# Train_158: scab
# Train_1580: scab
# Train_1581: rust
# Train_1582: rust
# Train_1583: healthy
# Train_1584: rust
# Train_1585: healthy
# Train_1586: scab
# Train_1587: healthy
# Train_1588: scab
# Train_1589: scab
# Train_159: rust
# Train_1590: healthy
# Train_1591: rust
# Train_1592: rust
# Train_1593: healthy
# Train_1594: rust
# Train_1595: rust
# Train_1596: rust
# Train_1597: healthy
# Train_1598: healthy
# Train_1599: rust
# Train_16: scab
# Train_160: scab
# Train_1600: healthy
# Train_1601: healthy
# Train_1602: rust
# Train_1603: rust
# Train_1604: healthy
# Train_1605: healthy
# Train_1606: rust
# Train_1607: rust
# Train_1608: healthy
# Train_1609: scab
# Train_161: scab
# Train_1610: healthy
# Train_1611: scab
# Train_1612: healthy
# Train_1613: rust
# Train_1614: healthy
# Train_1615: healthy
# Train_1616: healthy
# Train_1617: healthy
# Train_1618: scab
# Train_1619: scab
# Train_162: healthy
# Train_1620: rust
# Train_1621: healthy
# Train_1622: scab
# Train_1623: scab
# Train_1624: rust
# Train_1625: rust
# Train_1626: rust
# Train_1627: scab
# Train_1628: scab
# Train_1629: scab
# Train_163: scab
# Train_1630: rust
# Train_1631: healthy
# Train_1632: healthy
# Train_1633: rust
# Train_1634: healthy
# Train_1635: healthy
# Train_1636: rust
# Train_1637: scab
# Train_1638: scab
# Train_1639: scab
# Train_164: rust
# Train_1640: rust
# Train_1641: multiple_diseases
# Train_1642: rust
# Train_1643: rust
# Train_1644: rust
# Train_1645: scab
# Train_1646: healthy
# Train_1647: scab
# Train_1648: multiple_diseases
# Train_1649: rust
# Train_165: rust
# Train_1650: scab
# Train_1651: rust
# Train_1652: scab
# Train_1653: healthy
# Train_1654: healthy
# Train_1655: rust
# Train_1656: healthy
# Train_1657: rust
# Train_1658: scab
# Train_1659: scab
# Train_166: scab
# Train_1660: scab
# Train_1661: healthy
# Train_1662: multiple_diseases
# Train_1663: rust
# Train_1664: healthy
# Train_1665: rust
# Train_1666: rust
# Train_1667: healthy
# Train_1668: rust
# Train_1669: scab
# Train_167: healthy
# Train_1670: healthy
# Train_1671: rust
# Train_1672: healthy
# Train_1673: scab
# Train_1674: rust
# Train_1675: healthy
# Train_1676: healthy
# Train_1677: rust
# Train_1678: rust
# Train_1679: rust
# Train_168: scab
# Train_1680: scab
# Train_1681: healthy
# Train_1682: healthy
# Train_1683: healthy
# Train_1684: rust
# Train_1685: scab
# Train_1686: rust
# Train_1687: healthy
# Train_1688: scab
# Train_1689: rust
# Train_169: healthy
# Train_1690: scab
# Train_1691: healthy
# Train_1692: scab
# Train_1693: healthy
# Train_1694: healthy
# Train_1695: rust
# Train_1696: scab
# Train_1697: healthy
# Train_1698: rust
# Train_1699: rust
# Train_17: scab
# Train_170: scab
# Train_1700: scab
# Train_1701: scab
# Train_1702: scab
# Train_1703: scab
# Train_1704: scab
# Train_1705: scab
# Train_1706: healthy
# Train_1707: rust
# Train_1708: scab
# Train_1709: rust
# Train_171: rust
# Train_1710: rust
# Train_1711: scab
# Train_1712: rust
# Train_1713: scab
# Train_1714: rust
# Train_1715: scab
# Train_1716: scab
# Train_1717: scab
# Train_1718: scab
# Train_1719: scab
# Train_172: scab
# Train_1720: rust
# Train_1721: healthy
# Train_1722: rust
# Train_1723: rust
# Train_1724: healthy
# Train_1725: rust
# Train_1726: rust
# Train_1727: scab
# Train_1728: scab
# Train_1729: rust
# Train_173: scab
# Train_1730: rust
# Train_1731: healthy
# Train_1732: healthy
# Train_1733: healthy
# Train_1734: healthy
# Train_1735: healthy
# Train_1736: rust
# Train_1737: scab
# Train_1738: rust
# Train_1739: scab
# Train_174: healthy
# Train_1740: rust
# Train_1741: healthy
# Train_1742: scab
# Train_1743: rust
# Train_1744: scab
# Train_1745: rust
# Train_1746: rust
# Train_1747: scab
# Train_1748: healthy
# Train_1749: rust
# Train_175: healthy
# Train_1750: scab
# Train_1751: scab
# Train_1752: rust
# Train_1753: rust
# Train_1754: scab
# Train_1755: rust
# Train_1756: scab
# Train_1757: scab
# Train_1758: scab
# Train_1759: scab
# Train_176: scab
# Train_1760: healthy
# Train_1761: scab
# Train_1762: scab
# Train_1763: rust
# Train_1764: rust
# Train_1765: scab
# Train_1766: rust
# Train_1767: scab
# Train_1768: scab
# Train_1769: healthy
# Train_177: scab
# Train_1770: rust
# Train_1771: rust
# Train_1772: rust
# Train_1773: rust
# Train_1774: healthy
# Train_1775: scab
# Train_1776: healthy
# Train_1777: healthy
# Train_1778: healthy
# Train_1779: multiple_diseases
# Train_178: scab
# Train_1780: scab
# Train_1781: healthy
# Train_1782: rust
# Train_1783: rust
# Train_1784: multiple_diseases
# Train_1785: rust
# Train_1786: rust
# Train_1787: scab
# Train_1788: scab
# Train_1789: healthy
# Train_179: healthy
# Train_1790: rust
# Train_1791: rust
# Train_1792: rust
# Train_1793: scab
# Train_1794: healthy
# Train_1795: rust
# Train_1796: rust
# Train_1797: rust
# Train_1798: rust
# Train_1799: scab
# Train_18: healthy
# Train_180: rust
# Train_1800: scab
# Train_1801: scab
# Train_1802: rust
# Train_1803: rust
# Train_1804: rust
# Train_1805: rust
# Train_1806: scab
# Train_1807: healthy
# Train_1808: healthy
# Train_1809: scab
# Train_181: rust
# Train_1810: healthy
# Train_1811: rust
# Train_1812: scab
# Train_1813: rust
# Train_1814: scab
# Train_1815: scab
# Train_1816: scab
# Train_1817: healthy
# Train_1818: rust
# Train_1819: rust
# Train_182: scab
# Train_1820: scab
# Train_183: rust
# Train_184: rust
# Train_185: scab
# Train_186: scab
# Train_187: rust
# Train_188: scab
# Train_189: scab
# Train_19: rust
# Train_190: scab
# Train_191: scab
# Train_192: scab
# Train_193: rust
# Train_194: scab
# Train_195: healthy
# Train_196: rust
# Train_197: scab
# Train_198: rust
# Train_199: healthy
# Train_2: healthy
# Train_20: scab
# Train_200: rust
# Train_201: healthy
# Train_202: rust
# Train_203: scab
# Train_204: scab
# Train_205: rust
# Train_206: healthy
# Train_207: scab
# Train_208: rust
# Train_209: scab
# Train_21: healthy
# Train_210: scab
# Train_211: scab
# Train_212: rust
# Train_213: healthy
# Train_214: scab
# Train_215: healthy
# Train_216: scab
# Train_217: rust
# Train_218: rust
# Train_219: healthy
# Train_22: scab
# Train_220: scab
# Train_221: healthy
# Train_222: scab
# Train_223: rust
# Train_224: healthy
# Train_225: rust
# Train_226: rust
# Train_227: scab
# Train_228: rust
# Train_229: scab
# Train_23: scab
# Train_230: scab
# Train_231: rust
# Train_232: scab
# Train_233: rust
# Train_234: scab
# Train_235: scab
# Train_236: rust
# Train_237: multiple_diseases
# Train_238: rust
# Train_239: scab
# Train_24: healthy
# Train_240: rust
# Train_241: rust
# Train_242: scab
# Train_243: scab
# Train_244: rust
# Train_245: rust
# Train_246: rust
# Train_247: healthy
# Train_248: healthy
# Train_249: healthy
# Train_25: scab
# Train_250: scab
# Train_251: scab
# Train_252: scab
# Train_253: scab
# Train_254: rust
# Train_255: scab
# Train_256: scab
# Train_257: rust
# Train_258: scab
# Train_259: rust
# Train_26: rust
# Train_260: scab
# Train_261: healthy
# Train_262: scab
# Train_263: healthy
# Train_264: healthy
# Train_265: healthy
# Train_266: healthy
# Train_267: scab
# Train_268: scab
# Train_269: rust
# Train_27: scab
# Train_270: scab
# Train_271: healthy
# Train_272: scab
# Train_273: healthy
# Train_274: rust
# Train_275: rust
# Train_276: scab
# Train_277: rust
# Train_278: healthy
# Train_279: rust
# Train_28: scab
# Train_280: scab
# Train_281: scab
# Train_282: healthy
# Train_283: scab
# Train_284: rust
# Train_285: rust
# Train_286: rust
# Train_287: healthy
# Train_288: rust
# Train_289: rust
# Train_29: scab
# Train_290: scab
# Train_291: healthy
# Train_292: healthy
# Train_293: scab
# Train_294: rust
# Train_295: healthy
# Train_296: scab
# Train_297: scab
# Train_298: scab
# Train_299: rust
# Train_3: rust
# Train_30: scab
# Train_300: healthy
# Train_301: rust
# Train_302: rust
# Train_303: rust
# Train_304: healthy
# Train_305: scab
# Train_306: scab
# Train_307: healthy
# Train_308: scab
# Train_309: scab
# Train_31: scab
# Train_310: scab
# Train_311: healthy
# Train_312: scab
# Train_313: rust
# Train_314: rust
# Train_315: scab
# Train_316: scab
# Train_317: healthy
# Train_318: rust
# Train_319: scab
# Train_32: scab
# Train_320: healthy
# Train_321: rust
# Train_322: rust
# Train_323: healthy
# Train_324: healthy
# Train_325: scab
# Train_326: rust
# Train_327: rust
# Train_328: rust
# Train_329: healthy
# Train_33: healthy
# Train_330: healthy
# Train_331: rust
# Train_332: scab
# Train_333: rust
# Train_334: rust
# Train_335: rust
# Train_336: rust
# Train_337: healthy
# Train_338: scab
# Train_339: healthy
# Train_34: rust
# Train_340: rust
# Train_341: rust
# Train_342: rust
# Train_343: scab
# Train_344: rust
# Train_345: rust
# Train_346: rust
# Train_347: rust
# Train_348: healthy
# Train_349: scab
# Train_35: rust
# Train_350: rust
# Train_351: scab
# Train_352: rust
# Train_353: scab
# Train_354: scab
# Train_355: scab
# Train_356: healthy
# Train_357: healthy
# Train_358: scab
# Train_359: healthy
# Train_36: healthy
# Train_360: rust
# Train_361: scab
# Train_362: scab
# Train_363: scab
# Train_364: scab
# Train_365: healthy
# Train_366: healthy
# Train_367: healthy
# Train_368: healthy
# Train_369: rust
# Train_37: rust
# Train_370: scab
# Train_371: healthy
# Train_372: scab
# Train_373: rust
# Train_374: scab
# Train_375: healthy
# Train_376: healthy
# Train_377: scab
# Train_378: healthy
# Train_379: multiple_diseases
# Train_38: rust
# Train_380: healthy
# Train_381: rust
# Train_382: scab
# Train_383: healthy
# Train_384: rust
# Train_385: healthy
# Train_386: healthy
# Train_387: rust
# Train_388: scab
# Train_389: healthy
# Train_39: rust
# Train_390: rust
# Train_391: rust
# Train_392: healthy
# Train_393: scab
# Train_394: rust
# Train_395: rust
# Train_396: healthy
# Train_397: healthy
# Train_398: scab
# Train_399: rust
# Train_4: rust
# Train_40: scab
# Train_400: rust
# Train_401: scab
# Train_402: rust
# Train_403: rust
# Train_404: healthy
# Train_405: healthy
# Train_406: healthy
# Train_407: scab
# Train_408: rust
# Train_409: rust
# Train_41: scab
# Train_410: rust
# Train_411: rust
# Train_412: healthy
# Train_413: rust
# Train_414: scab
# Train_415: healthy
# Train_416: rust
# Train_417: healthy
# Train_418: scab
# Train_419: scab
# Train_42: scab
# Train_420: healthy
# Train_421: healthy
# Train_422: rust
# Train_423: scab
# Train_424: scab
# Train_425: healthy
# Train_426: rust
# Train_427: healthy
# Train_428: multiple_diseases
# Train_429: scab
# Train_43: healthy
# Train_430: healthy
# Train_431: scab
# Train_432: healthy
# Train_433: healthy
# Train_434: rust
# Train_435: rust
# Train_436: scab
# Train_437: scab
# Train_438: healthy
# Train_439: healthy
# Train_44: scab
# Train_440: rust
# Train_441: rust
# Train_442: scab
# Train_443: healthy
# Train_444: healthy
# Train_445: rust
# Train_446: healthy
# Train_447: rust
# Train_448: rust
# Train_449: scab
# Train_45: rust
# Train_450: healthy
# Train_451: rust
# Train_452: healthy
# Train_453: rust
# Train_454: scab
# Train_455: rust
# Train_456: rust
# Train_457: scab
# Train_458: rust
# Train_459: healthy
# Train_46: healthy
# Train_460: healthy
# Train_461: scab
# Train_462: rust
# Train_463: scab
# Train_464: rust
# Train_465: rust
# Train_466: healthy
# Train_467: rust
# Train_468: rust
# Train_469: rust
# Train_47: rust
# Train_470: scab
# Train_471: scab
# Train_472: rust
# Train_473: scab
# Train_474: healthy
# Train_475: healthy
# Train_476: healthy
# Train_477: scab
# Train_478: healthy
# Train_479: rust
# Train_48: scab
# Train_480: scab
# Train_481: rust
# Train_482: rust
# Train_483: rust
# Train_484: rust
# Train_485: rust
# Train_486: rust
# Train_487: rust
# Train_488: scab
# Train_489: scab
# Train_49: scab
# Train_490: scab
# Train_491: healthy
# Train_492: rust
# Train_493: scab
# Train_494: scab
# Train_495: rust
# Train_496: healthy
# Train_497: rust
# Train_498: scab
# Train_499: rust
# Train_5: healthy
# Train_50: rust
# Train_500: rust
# Train_501: rust
# Train_502: scab
# Train_503: scab
# Train_504: healthy
# Train_505: scab
# Train_506: rust
# Train_507: rust
# Train_508: rust
# Train_509: rust
# Train_51: scab
# Train_510: rust
# Train_511: rust
# Train_512: scab
# Train_513: rust
# Train_514: rust
# Train_515: rust
# Train_516: rust
# Train_517: rust
# Train_518: rust
# Train_519: rust
# Train_52: scab
# Train_520: scab
# Train_521: healthy
# Train_522: rust
# Train_523: rust
# Train_524: scab
# Train_525: healthy
# Train_526: healthy
# Train_527: scab
# Train_528: rust
# Train_529: healthy
# Train_53: healthy
# Train_530: healthy
# Train_531: healthy
# Train_532: healthy
# Train_533: rust
# Train_534: rust
# Train_535: scab
# Train_536: rust
# Train_537: healthy
# Train_538: scab
# Train_539: rust
# Train_54: healthy
# Train_540: scab
# Train_541: rust
# Train_542: rust
# Train_543: rust
# Train_544: healthy
# Train_545: healthy
# Train_546: healthy
# Train_547: healthy
# Train_548: scab
# Train_549: rust
# Train_55: healthy
# Train_550: healthy
# Train_551: healthy
# Train_552: scab
# Train_553: scab
# Train_554: scab
# Train_555: scab
# Train_556: scab
# Train_557: scab
# Train_558: healthy
# Train_559: scab
# Train_56: scab
# Train_560: rust
# Train_561: rust
# Train_562: healthy
# Train_563: healthy
# Train_564: rust
# Train_565: scab
# Train_566: healthy
# Train_567: rust
# Train_568: scab
# Train_569: healthy
# Train_57: rust
# Train_570: scab
# Train_571: rust
# Train_572: healthy
# Train_573: healthy
# Train_574: rust
# Train_575: rust
# Train_576: scab
# Train_577: rust
# Train_578: rust
# Train_579: healthy
# Train_58: rust
# Train_580: scab
# Train_581: scab
# Train_582: rust
# Train_583: scab
# Train_584: scab
# Train_585: rust
# Train_586: rust
# Train_587: healthy
# Train_588: rust
# Train_589: scab
# Train_59: rust
# Train_590: rust
# Train_591: healthy
# Train_592: healthy
# Train_593: scab
# Train_594: rust
# Train_595: healthy
# Train_596: rust
# Train_597: healthy
# Train_598: rust
# Train_599: scab
# Train_6: scab
# Train_60: rust
# Train_600: scab
# Train_601: healthy
# Train_602: rust
# Train_603: healthy
# Train_604: scab
# Train_605: rust
# Train_606: rust
# Train_607: rust
# Train_608: healthy
# Train_609: rust
# Train_61: scab
# Train_610: rust
# Train_611: rust
# Train_612: scab
# Train_613: rust
# Train_614: scab
# Train_615: rust
# Train_616: healthy
# Train_617: scab
# Train_618: healthy
# Train_619: healthy
# Train_62: multiple_diseases
# Train_620: rust
# Train_621: healthy
# Train_622: healthy
# Train_623: rust
# Train_624: scab
# Train_625: scab
# Train_626: scab
# Train_627: rust
# Train_628: scab
# Train_629: scab
# Train_63: rust
# Train_630: healthy
# Train_631: scab
# Train_632: rust
# Train_633: scab
# Train_634: rust
# Train_635: healthy
# Train_636: scab
# Train_637: scab
# Train_638: scab
# Train_639: rust
# Train_64: rust
# Train_640: rust
# Train_641: scab
# Train_642: healthy
# Train_643: rust
# Train_644: healthy
# Train_645: rust
# Train_646: healthy
# Train_647: healthy
# Train_648: healthy
# Train_649: scab
# Train_65: scab
# Train_650: healthy
# Train_651: scab
# Train_652: rust
# Train_653: scab
# Train_654: rust
# Train_655: scab
# Train_656: rust
# Train_657: healthy
# Train_658: scab
# Train_659: scab
# Train_66: healthy
# Train_660: healthy
# Train_661: scab
# Train_662: scab
# Train_663: rust
# Train_664: scab
# Train_665: healthy
# Train_666: rust
# Train_667: rust
# Train_668: rust
# Train_669: scab
# Train_67: rust
# Train_670: rust
# Train_671: healthy
# Train_672: rust
# Train_673: scab
# Train_674: scab
# Train_675: healthy
# Train_676: healthy
# Train_677: scab
# Train_678: healthy
# Train_679: healthy
# Train_68: healthy
# Train_680: scab
# Train_681: scab
# Train_682: scab
# Train_683: rust
# Train_684: healthy
# Train_685: healthy
# Train_686: scab
# Train_687: healthy
# Train_688: scab
# Train_689: rust
# Train_69: rust
# Train_690: rust
# Train_691: healthy
# Train_692: scab
# Train_693: rust
# Train_694: healthy
# Train_695: rust
# Train_696: scab
# Train_697: rust
# Train_698: scab
# Train_699: scab
# Train_7: scab
# Train_70: healthy
# Train_700: rust
# Train_701: scab
# Train_702: scab
# Train_703: healthy
# Train_704: rust
# Train_705: rust
# Train_706: rust
# Train_707: rust
# Train_708: scab
# Train_709: scab
# Train_71: rust
# Train_710: rust
# Train_711: rust
# Train_712: rust
# Train_713: rust
# Train_714: rust
# Train_715: healthy
# Train_716: scab
# Train_717: scab
# Train_718: rust
# Train_719: rust
# Train_72: healthy
# Train_720: healthy
# Train_721: scab
# Train_722: rust
# Train_723: scab
# Train_724: rust
# Train_725: healthy
# Train_726: scab
# Train_727: scab
# Train_728: rust
# Train_729: scab
# Train_73: scab
# Train_730: healthy
# Train_731: healthy
# Train_732: healthy
# Train_733: scab
# Train_734: rust
# Train_735: healthy
# Train_736: scab
# Train_737: healthy
# Train_738: rust
# Train_739: rust
# Train_74: scab
# Train_740: scab
# Train_741: rust
# Train_742: rust
# Train_743: rust
# Train_744: rust
# Train_745: rust
# Train_746: healthy
# Train_747: healthy
# Train_748: scab
# Train_749: rust
# Train_75: rust
# Train_750: rust
# Train_751: scab
# Train_752: healthy
# Train_753: healthy
# Train_754: rust
# Train_755: healthy
# Train_756: scab
# Train_757: scab
# Train_758: scab
# Train_759: rust
# Train_76: scab
# Train_760: rust
# Train_761: healthy
# Train_762: scab
# Train_763: rust
# Train_764: rust
# Train_765: scab
# Train_766: rust
# Train_767: rust
# Train_768: healthy
# Train_769: healthy
# Train_77: healthy
# Train_770: scab
# Train_771: scab
# Train_772: healthy
# Train_773: healthy
# Train_774: healthy
# Train_775: scab
# Train_776: healthy
# Train_777: healthy
# Train_778: rust
# Train_779: rust
# Train_78: scab
# Train_780: scab
# Train_781: healthy
# Train_782: healthy
# Train_783: scab
# Train_784: rust
# Train_785: scab
# Train_786: healthy
# Train_787: scab
# Train_788: healthy
# Train_789: rust
# Train_79: scab
# Train_790: rust
# Train_791: rust
# Train_792: scab
# Train_793: scab
# Train_794: healthy
# Train_795: scab
# Train_796: rust
# Train_797: scab
# Train_798: rust
# Train_799: rust
# Train_8: scab
# Train_80: scab
# Train_800: healthy
# Train_801: scab
# Train_802: healthy
# Train_803: scab
# Train_804: rust
# Train_805: healthy
# Train_806: scab
# Train_807: healthy
# Train_808: rust
# Train_809: healthy
# Train_81: rust
# Train_810: scab
# Train_811: healthy
# Train_812: healthy
# Train_813: scab
# Train_814: rust
# Train_815: healthy
# Train_816: rust
# Train_817: healthy
# Train_818: scab
# Train_819: scab
# Train_82: rust
# Train_820: scab
# Train_821: rust
# Train_822: rust
# Train_823: scab
# Train_824: scab
# Train_825: rust
# Train_826: healthy
# Train_827: rust
# Train_828: rust
# Train_829: rust
# Train_83: scab
# Train_830: rust
# Train_831: scab
# Train_832: rust
# Train_833: healthy
# Train_834: healthy
# Train_835: healthy
# Train_836: rust
# Train_837: rust
# Train_838: scab
# Train_839: healthy
# Train_84: scab
# Train_840: rust
# Train_841: rust
# Train_842: scab
# Train_843: rust
# Train_844: scab
# Train_845: scab
# Train_846: scab
# Train_847: rust
# Train_848: rust
# Train_849: healthy
# Train_85: scab
# Train_850: healthy
# Train_851: healthy
# Train_852: scab
# Train_853: rust
# Train_854: scab
# Train_855: rust
# Train_856: rust
# Train_857: scab
# Train_858: scab
# Train_859: scab
# Train_86: rust
# Train_860: rust
# Train_861: scab
# Train_862: scab
# Train_863: healthy
# Train_864: healthy
# Train_865: rust
# Train_866: healthy
# Train_867: rust
# Train_868: scab
# Train_869: scab
# Train_87: rust
# Train_870: scab
# Train_871: scab
# Train_872: healthy
# Train_873: rust
# Train_874: rust
# Train_875: rust
# Train_876: rust
# Train_877: healthy
# Train_878: scab
# Train_879: scab
# Train_88: rust
# Train_880: healthy
# Train_881: healthy
# Train_882: healthy
# Train_883: scab
# Train_884: rust
# Train_885: scab
# Train_886: rust
# Train_887: healthy
# Train_888: rust
# Train_889: rust
# Train_89: rust
# Train_890: healthy
# Train_891: scab
# Train_892: rust
# Train_893: healthy
# Train_894: scab
# Train_895: healthy
# Train_896: healthy
# Train_897: healthy
# Train_898: scab
# Train_899: scab
# Train_9: healthy
# Train_90: healthy
# Train_900: rust
# Train_901: healthy
# Train_902: scab
# Train_903: healthy
# Train_904: scab
# Train_905: healthy
# Train_906: scab
# Train_907: healthy
# Train_908: healthy
# Train_909: healthy
# Train_91: scab
# Train_910: scab
# Train_911: rust
# Train_912: rust
# Train_913: rust
# Train_914: healthy
# Train_915: healthy
# Train_916: rust
# Train_917: scab
# Train_918: healthy
# Train_919: healthy
# Train_92: rust
# Train_920: rust
# Train_921: healthy
# Train_922: scab
# Train_923: healthy
# Train_924: rust
# Train_925: rust
# Train_926: scab
# Train_927: scab
# Train_928: rust
# Train_929: healthy
# Train_93: rust
# Train_930: scab
# Train_931: rust
# Train_932: scab
# Train_933: scab
# Train_934: healthy
# Train_935: healthy
# Train_936: healthy
# Train_937: healthy
# Train_938: rust
# Train_939: healthy
# Train_94: healthy
# Train_940: rust
# Train_941: scab
# Train_942: healthy
# Train_943: rust
# Train_944: scab
# Train_945: rust
# Train_946: scab
# Train_947: healthy
# Train_948: healthy
# Train_949: healthy
# Train_95: rust
# Train_950: rust
# Train_951: healthy
# Train_952: scab
# Train_953: rust
# Train_954: scab
# Train_955: scab
# Train_956: healthy
# Train_957: rust
# Train_958: healthy
# Train_959: scab
# Train_96: rust
# Train_960: healthy
# Train_961: healthy
# Train_962: rust
# Train_963: healthy
# Train_964: scab
# Train_965: rust
# Train_966: healthy
# Train_967: scab
# Train_968: healthy
# Train_969: healthy
# Train_97: rust
# Train_970: scab
# Train_971: rust
# Train_972: scab
# Train_973: scab
# Train_974: scab
# Train_975: rust
# Train_976: rust
# Train_977: healthy
# Train_978: rust
# Train_979: healthy
# Train_98: rust
# Train_980: healthy
# Train_981: healthy
# Train_982: rust
# Train_983: healthy
# Train_984: scab
# Train_985: rust
# Train_986: scab
# Train_987: rust
# Train_988: scab
# Train_989: healthy
# Train_99: healthy
# Train_990: scab
# Train_991: scab
# Train_992: scab
# Train_993: scab
# Train_994: scab
# Train_995: rust
# Train_996: rust
# Train_997: scab
# Train_998: scab
# Train_999: scab

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def save_confusion_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['healthy', 'multiple_diseases', 'rust', 'scab'],
                yticklabels=['healthy', 'multiple_diseases', 'rust', 'scab'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - {model_name}')
    plt.tight_layout()
    plt.savefig(f'{model_name}_confusion_matrix.png')
    plt.close()

# Example for SVM
y_pred_svm = svm_model.predict(X_test_scaled)
save_confusion_matrix(y_test, y_pred_svm, "SVM")

# %%
accuracies = {
    'SVM': accuracy_score(y_test, svm_model.predict(X_test_scaled)),
    'Random Forest': accuracy_score(y_test, rf_model.predict(X_test)),
    'XGBoost': accuracy_score(y_test, xgb_model.predict(X_test))
}

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x=list(accuracies.keys()), y=list(accuracies.values()), palette='viridis')
plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.tight_layout()
plt.savefig("model_accuracy_comparison.png")
plt.close()
# Out:
# C:\Users\Aagaaz Kapoor\AppData\Local\Temp\ipykernel_17388\946304589.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(accuracies.keys()), y=list(accuracies.values()), palette='viridis')

# %%
from sklearn.metrics import classification_report

# SVM Example
report = classification_report(y_test, y_pred_svm, target_names=['healthy', 'multiple_diseases', 'rust', 'scab'])
with open("svm_classification_report.txt", "w") as f:
    f.write(report)

# %%
print("Length of image_ids:", len(image_ids))
print("Length of predicted_labels:", len(predicted_labels))
# Out:
# Length of image_ids: 3642
# Length of predicted_labels: 365

# %%
image_ids = [f"test_img_{i}" for i in range(len(predicted_labels))]

# %%
# Only if you're using real test images (not internal sklearn test split)
# Make sure image_ids and y_pred are from the same test set
image_ids = [f"test_img_{i}" for i in range(len(predicted_labels))]  # if actual names are missing

results_df = pd.DataFrame({
    'image_id': image_ids,
    'predicted_label': predicted_labels
})

results_df.to_csv("svm_predictions.csv", index=False)
print("✅ Predictions saved to svm_predictions.csv")
# Out:
# ✅ Predictions saved to svm_predictions.csv

# %%
import pandas as pd

# Map predicted labels
label_map = {0: 'healthy', 1: 'multiple_diseases', 2: 'rust', 3: 'scab'}
predicted_labels = [label_map[i] for i in y_pred_svm]

# Assuming you have image IDs for the test set
results_df = pd.DataFrame({
    'image_id': image_ids,  # Make sure this list is available from earlier
    'predicted_label': predicted_labels
})

results_df.to_csv("svm_predictions.csv", index=False)
